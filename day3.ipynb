# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnipalli-Naveen/Assignment-python/blob/master/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alti = input("enter a number_ ")
alti= int(alti)
if alti <1000:
    print("land the plane")
elif alti >5000 :
    print("Go Around and land later")
else:
    print("Bring down to 1000ft")
# Out:
# enter a number_ 700
# land the plane

# %%
for num in range(2,200):
  for i in range(2,num):
          if(num%i)==0:
            print(num,"not prime number")
            break
  else:
              print(num,"prime number")
# Out:
# 2 prime number
# 3 prime number
# 4 not prime number
# 5 prime number
# 6 not prime number
# 7 prime number
# 8 not prime number
# 9 not prime number
# 10 not prime number
# 11 prime number
# 12 not prime number
# 13 prime number
# 14 not prime number
# 15 not prime number
# 16 not prime number
# 17 prime number
# 18 not prime number
# 19 prime number
# 20 not prime number
# 21 not prime number
# 22 not prime number
# 23 prime number
# 24 not prime number
# 25 not prime number
# 26 not prime number
# 27 not prime number
# 28 not prime number
# 29 prime number
# 30 not prime number
# 31 prime number
# 32 not prime number
# 33 not prime number
# 34 not prime number
# 35 not prime number
# 36 not prime number
# 37 prime number
# 38 not prime number
# 39 not prime number
# 40 not prime number
# 41 prime number
# 42 not prime number
# 43 prime number
# 44 not prime number
# 45 not prime number
# 46 not prime number
# 47 prime number
# 48 not prime number
# 49 not prime number
# ...
